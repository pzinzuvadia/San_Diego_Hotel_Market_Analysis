# %%
import pandas as pd

# %%
file_path = 'From_12_1_to_12_31_30_days_total_SD_hotels_list.csv'

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                                hotel  \
# 0                 Beauty of Point Loma on the Harbor
# 1                         San Diego Marriott Del Mar
# 2    Artfully-styled bungalow in the heart of it all
# 3          Fairfield Inn & Suites San Diego Old Town
# 4                                         OB Holiday
# ..                                               ...
# 246     Studio with Large Balcony- San Diego Gateway
# 247                        Legacy Resort Hotel & Spa
# 248                         Grande Colonial La Jolla
# 249                                  The Pearl Hotel
# 250                         The Inn at Sunset Cliffs
#
#                     hotel_location    price
# 0            Point Loma, San Diego   $3,953
# 1         Carmel Valley, San Diego   $5,370
# 2                        San Diego   $5,120
# 3              Old Town, San Diego   $5,531
# 4           Ocean Beach, San Diego   $8,919
# ..                             ...      ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                                hotel  \
# 0                 Beauty of Point Loma on the Harbor
# 1                         San Diego Marriott Del Mar
# 2    Artfully-styled bungalow in the heart of it all
# 3          Fairfield Inn & Suites San Diego Old Town
# 4                                         OB Holiday
# ..                                               ...
# 246     Studio with Large Balcony- San Diego Gateway
# 247                        Legacy Resort Hotel & Spa
# 248                         Grande Colonial La Jolla
# 249                                  The Pearl Hotel
# 250                         The Inn at Sunset Cliffs
#
#                     hotel_location    price
# 0            Point Loma, San Diego   $3,953
# 1         Carmel Valley, San Diego   $5,370
# 2                        San Diego   $5,120
# 3              Old Town, San Diego   $5,531
# 4           Ocean Beach, San Diego   $8,919
# ..                             ...      ...
# ...

# %%
df.reset_index(drop=True)
# Out:
#                                                hotel  \
# 0                 Beauty of Point Loma on the Harbor
# 1                         San Diego Marriott Del Mar
# 2    Artfully-styled bungalow in the heart of it all
# 3          Fairfield Inn & Suites San Diego Old Town
# 4                                         OB Holiday
# ..                                               ...
# 217     Studio with Large Balcony- San Diego Gateway
# 218                        Legacy Resort Hotel & Spa
# 219                         Grande Colonial La Jolla
# 220                                  The Pearl Hotel
# 221                         The Inn at Sunset Cliffs
#
#                     hotel_location    price
# 0            Point Loma, San Diego   $3,953
# 1         Carmel Valley, San Diego   $5,370
# 2                        San Diego   $5,120
# 3              Old Town, San Diego   $5,531
# 4           Ocean Beach, San Diego   $8,919
# ..                             ...      ...
# ...

# %%
output_file_path = '30night_remove_duplicate.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)

print(f"Deduplicated file saved to {output_file_path}")
# Out:
# Deduplicated file saved to 30night_remove_duplicate.csv
